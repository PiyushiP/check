# %%
import sys


model_type='mobilenetv2'
user='anis'
PROJECT_PATH='/content/drive/My Drive/udemy-deep-learning-in-practice/03-transfer-learning/03-train-models/'
print('PROJECT_PATH: ',PROJECT_PATH)
LOGFILE_PATH=PROJECT_PATH+'log/'+model_type+'/'+model_type+'-by-'+TYPE+'-training-log.csv'

sys.path.append(PROJECT_PATH)
import riotu_computer_vision_lib  
from riotu_computer_vision_lib import *
# Out:
# PROJECT_PATH:  /content/drive/My Drive/udemy-deep-learning-in-practice/03-transfer-learning/03-train-models/
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0f11f377157b> in <module>()
#       6 PROJECT_PATH='/content/drive/My Drive/udemy-deep-learning-in-practice/03-transfer-learning/03-train-models/'
#       7 print('PROJECT_PATH: ',PROJECT_PATH)
# ----> 8 LOGFILE_PATH=PROJECT_PATH+'log/'+model_type+'/'+model_type+'-by-'+TYPE+'-training-log.csv'
#       9
#      10 sys.path.append(PROJECT_PATH)
#
# NameError: name 'TYPE' is not defined

# %%
riotu_computer_vision_lib.plot_loss_accuracy_from_csv(LOGFILE_PATH)
